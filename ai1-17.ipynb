# %%
import pyfcctab as fcc
import astropy.units as units
from termcolor import colored

# %%
tables = fcc.load()

# %%
ai_ranges = [
    [17.7*units.GHz, 18.6*units.GHz],
    [18.8*units.GHz, 19.3*units.GHz],
    [19.7*units.GHz, 20.2*units.GHz],
    [27.5*units.GHz, 29.1*units.GHz],
    [29.5*units.GHz, 30.0*units.GHz] 
]

# %%
for ai in ai_ranges:
    print (colored(f"================================ {ai[0]}-{ai[1]}", attrs=["bold"]))
    bands = tables.itu.get_bands(ai[0], ai[1], adjacent=True)
    for b in bands:
        print(f"----------- {b.range_str()}")
        print(b.to_str(highlight_allocations=True))
# Out:
# ================================ 17.7 GHz-18.6 GHz
# ----------- 17.3 GHz-17.7 GHz
# 17.3 GHz-17.7 GHz [R1]
# FIXED-SATELLITE (Earth-to-space) 5.516 (space-to-Earth) 5.516A 5.516B
# Radiolocation
# 5.514
# ----------- 17.3 GHz-17.7 GHz
# 17.3 GHz-17.7 GHz [R2]
# FIXED-SATELLITE (Earth-to-space) 5.516
# BROADCASTING-SATELLITE
# Radiolocation
# 5.514 5.515
# ----------- 17.3 GHz-17.7 GHz
# 17.3 GHz-17.7 GHz [R3]
# FIXED-SATELLITE (Earth-to-space) 5.516
# Radiolocation
# 5.514
# ----------- 17.7 GHz-18.1 GHz
# 17.7 GHz-18.1 GHz [R1,R3]
# FIXED
# FIXED-SATELLITE (space-to-Earth) 5.484A (Earth-to-space) 5.516
# MOBILE
#
# ----------- 17.7 GHz-17.8 GHz
# 17.7 GHz-17.8 GHz [R2]
# FIXED
# FIXED-SATELLITE (space-to-Earth) 5.517 (Earth-to-space) 5.516
# BROADCASTING-SATELLITE
# Mobile
# 5.515
# ----------- 17.8 GHz-18.1 GHz
# 17.8 GHz-18.1 GHz [R2]
# FIXED
# FIXED-SATELLITE (space-to-Earth) 5.484A (Earth-to-space) 5.516
# MOBILE
# 5.519
# ----------- 18.1 GHz-18.4 GHz
# ...
